# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.graph_objects as go
import plotly.io as pio
import plotly.express as px

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot


from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, KFold
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet

import optuna
import xgboost as xgb

import warnings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter('ignore', pd.errors.SettingWithCopyWarning)
warnings.simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
scores_linear = pd.read_csv('~/Documents/AmesHousingML/model_building/masterScores_linear.csv') 
scores_lassoRidgeElastic = pd.read_csv('~/Documents/AmesHousingML/model_building/masterScores_lassoRidgeElastic.csv') 
scores_randomForest = pd.read_csv('~/Documents/AmesHousingML/model_building/masterScores_randomForest.csv') 
scores_xgboost = pd.read_csv('~/Documents/AmesHousingML/model_building/masterScores_xgboost.csv') 
scores_scikitGB = pd.read_csv('~/Documents/AmesHousingML/model_building/masterScores_scikitBoosting.csv') 
scores_catboost = pd.read_csv('~/Documents/AmesHousingML/model_building/masterScores_catboost.csv') 
scores_df = pd.concat([scores_linear, scores_lassoRidgeElastic, scores_randomForest, 
                       scores_xgboost, scores_scikitGB, scores_catboost], ignore_index=True)

# %%
scores_df

# output_file = '~/Documents/AmesHousingML/scores_old_test.csv'

# scores_df.to_csv(output_file, index=False, mode='w')

# print(f"DataFrame exported to '{output_file}' in the same working directory.")
# Out:
#                  Model                         data_process  r2_5kf_mean  \
# 0                  MLR              dummified_threeXOutlier     0.842156
# 1                  MLR        dummified_onlyNormalCondition     0.867671
# 2                  MLR                dummified_allOutliers     0.817061
# 3                lasso        dummifiedNoDrop_threeXOutlier     0.899725
# 4                lasso  dummifiedNoDrop_onlyNormalCondition     0.933296
# 5                lasso          dummifiedNoDrop_allOutliers     0.891631
# 6                ridge        dummifiedNoDrop_threeXOutlier     0.897200
# 7                ridge  dummifiedNoDrop_onlyNormalCondition     0.931033
# 8                ridge          dummifiedNoDrop_allOutliers     0.893286
# 9           elasticNet        dummifiedNoDrop_threeXOutlier     0.899543
# 10          elasticNet  dummifiedNoDrop_onlyNormalCondition     0.928942
# 11          elasticNet          dummifiedNoDrop_allOutliers     0.897469
# 12        randomForest                ordinal_threeXOutlier     0.900315
# 13        randomForest          ordinal_onlyNormalCondition     0.914710
# 14        randomForest                  ordinal_allOutliers     0.900703
# 15        randomForest              dummified_threeXOutlier     0.897686
# 16        randomForest        dummified_onlyNormalCondition     0.913220
# 17        randomForest                dummified_allOutliers     0.898702
# 18        randomForest        dummifiedNoDrop_threeXOutlier     0.898322
# 19        randomForest  dummifiedNoDrop_onlyNormalCondition     0.914006
# 20        randomForest          dummifiedNoDrop_allOutliers     0.898781
# 21  randomForest_tuned                ordinal_threeXOutlier     0.901742
# 22  randomForest_tuned          ordinal_onlyNormalCondition     0.915665
# 23  randomForest_tuned                  ordinal_allOutliers     0.901122
# 24  randomForest_tuned              dummified_threeXOutlier     0.899185
# 25  randomForest_tuned        dummified_onlyNormalCondition     0.913875
# 26  randomForest_tuned                dummified_allOutliers     0.899785
# 27  randomForest_tuned        dummifiedNoDrop_threeXOutlier     0.899853
# 28  randomForest_tuned  dummifiedNoDrop_onlyNormalCondition     0.914974
# 29  randomForest_tuned          dummifiedNoDrop_allOutliers     0.899727
# 30             xgboost                ordinal_threeXOutlier     0.902107
# 31             xgboost          ordinal_onlyNormalCondition     0.919789
# 32             xgboost                  ordinal_allOutliers     0.904445
# 33             xgboost              dummified_threeXOutlier     0.902148
# 34             xgboost        dummified_onlyNormalCondition     0.918049
# 35             xgboost                dummified_allOutliers     0.896948
# 36             xgboost        dummifiedNoDrop_threeXOutlier     0.900806
# 37             xgboost  dummifiedNoDrop_onlyNormalCondition     0.917838
# 38             xgboost          dummifiedNoDrop_allOutliers     0.904017
# 39       xgboost_tuned                ordinal_threeXOutlier     0.920908
# 40       xgboost_tuned          ordinal_onlyNormalCondition     0.945529
# 41       xgboost_tuned                  ordinal_allOutliers     0.923575
# 42       xgboost_tuned              dummified_threeXOutlier     0.924074
# 43       xgboost_tuned        dummified_onlyNormalCondition     0.948063
# 44       xgboost_tuned                dummified_allOutliers     0.925717
# 45       xgboost_tuned        dummifiedNoDrop_threeXOutlier     0.923597
# 46       xgboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.947439
# 47       xgboost_tuned          dummifiedNoDrop_allOutliers     0.930264
# 48           scikit_gb                ordinal_threeXOutlier     0.911408
# 49           scikit_gb          ordinal_onlyNormalCondition     0.934772
# 50           scikit_gb                  ordinal_allOutliers     0.913304
# 51           scikit_gb              dummified_threeXOutlier     0.910339
# 52           scikit_gb        dummified_onlyNormalCondition     0.933338
# 53           scikit_gb                dummified_allOutliers     0.914184
# 54           scikit_gb        dummifiedNoDrop_threeXOutlier     0.909811
# 55           scikit_gb  dummifiedNoDrop_onlyNormalCondition     0.934652
# 56           scikit_gb          dummifiedNoDrop_allOutliers     0.915274
# 57     scikit_gb_tuned                ordinal_threeXOutlier     0.920995
# 58     scikit_gb_tuned          ordinal_onlyNormalCondition     0.936694
# 59     scikit_gb_tuned                  ordinal_allOutliers     0.921607
# 60     scikit_gb_tuned              dummified_threeXOutlier     0.920443
# 61     scikit_gb_tuned        dummified_onlyNormalCondition     0.939710
# 62     scikit_gb_tuned                dummified_allOutliers     0.923153
# 63     scikit_gb_tuned        dummifiedNoDrop_threeXOutlier     0.920141
# 64     scikit_gb_tuned  dummifiedNoDrop_onlyNormalCondition     0.939211
# 65     scikit_gb_tuned          dummifiedNoDrop_allOutliers     0.925191
# 66            catboost                ordinal_threeXOutlier     0.921165
# 67            catboost          ordinal_onlyNormalCondition     0.938718
# 68            catboost                  ordinal_allOutliers     0.920792
# 69            catboost              dummified_threeXOutlier     0.920114
# 70            catboost        dummified_onlyNormalCondition     0.936520
# 71            catboost                dummified_allOutliers     0.920787
# 72            catboost        dummifiedNoDrop_threeXOutlier     0.919677
# 73            catboost  dummifiedNoDrop_onlyNormalCondition     0.935308
# 74            catboost          dummifiedNoDrop_allOutliers     0.920196
# 75      catboost_tuned                ordinal_threeXOutlier     0.927600
# 76      catboost_tuned          ordinal_onlyNormalCondition     0.945148
# 77      catboost_tuned                  ordinal_allOutliers     0.929929
# 78      catboost_tuned              dummified_threeXOutlier     0.928265
# 79      catboost_tuned        dummified_onlyNormalCondition     0.944098
# 80      catboost_tuned                dummified_allOutliers     0.930647
# 81      catboost_tuned        dummifiedNoDrop_threeXOutlier     0.925518
# 82      catboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.949319
# 83      catboost_tuned          dummifiedNoDrop_allOutliers     0.929797
#
#     rmse_5kf_mean
# 0    26329.284397
# 1    25700.214359
# 2    31730.596638
# 3    20901.033141
# 4    18203.509019
# 5    24067.062932
# 6    21132.978955
# 7    18516.622484
# 8    23982.313218
# 9    20924.639689
# 10   18789.042940
# 11   23648.736387
# 12   21063.431020
# 13   20557.040480
# 14   23595.621432
# 15   21340.686856
# 16   20743.874589
# 17   23829.250646
# 18   21273.463159
# 19   20643.846124
# 20   23817.907706
# 21   20919.551383
# 22   20459.591156
# 23   23539.259762
# 24   21189.949716
# 25   20678.952399
# 26   23693.736189
# 27   21114.207287
# 28   20542.862863
# 29   23701.772828
# 30   20866.299829
# 31   19881.826863
# 32   23142.592485
# 33   20859.072894
# 34   20111.383128
# 35   24052.156077
# 36   20997.812741
# 37   20159.872704
# 38   23207.145705
# 39   18584.941593
# 40   16422.205699
# 41   20693.007479
# 42   18271.906794
# 43   16036.566846
# 44   20392.851631
# 45   18238.710501
# 46   16140.245410
# 47   19749.971997
# 48   19722.476115
# 49   17913.941231
# 50   22060.491907
# 51   19856.202269
# 52   18117.270365
# 53   21953.270181
# 54   19905.529479
# 55   17922.807704
# 56   21797.217046
# 57   18588.952882
# 58   17624.355359
# 59   20968.784077
# 60   18689.378815
# 61   17222.610384
# 62   20747.332394
# 63   18742.033405
# 64   17275.923095
# 65   20478.870901
# 66   18681.014437
# 67   17394.528056
# 68   21088.095229
# 69   18766.314419
# 70   17705.618147
# 71   21054.910504
# 72   18851.435847
# 73   17909.736594
# 74   21164.979171
# 75   17793.103666
# 76   16470.914927
# 77   19829.620391
# 78   17773.822390
# 79   16615.987906
# 80   19721.529107
# 81   18059.373184
# 82   15834.922426
# 83   19839.780154

# %%
sorted_scores = scores_df.sort_values(by='r2_5kf_mean')
sorted_scores
# Out:
#                  Model                         data_process  r2_5kf_mean  \
# 2                  MLR                dummified_allOutliers     0.817061
# 0                  MLR              dummified_threeXOutlier     0.842156
# 1                  MLR        dummified_onlyNormalCondition     0.867671
# 5                lasso          dummifiedNoDrop_allOutliers     0.891631
# 8                ridge          dummifiedNoDrop_allOutliers     0.893286
# 35             xgboost                dummified_allOutliers     0.896948
# 6                ridge        dummifiedNoDrop_threeXOutlier     0.897200
# 11          elasticNet          dummifiedNoDrop_allOutliers     0.897469
# 15        randomForest              dummified_threeXOutlier     0.897686
# 18        randomForest        dummifiedNoDrop_threeXOutlier     0.898322
# 17        randomForest                dummified_allOutliers     0.898702
# 20        randomForest          dummifiedNoDrop_allOutliers     0.898781
# 24  randomForest_tuned              dummified_threeXOutlier     0.899185
# 9           elasticNet        dummifiedNoDrop_threeXOutlier     0.899543
# 3                lasso        dummifiedNoDrop_threeXOutlier     0.899725
# 29  randomForest_tuned          dummifiedNoDrop_allOutliers     0.899727
# 26  randomForest_tuned                dummified_allOutliers     0.899785
# 27  randomForest_tuned        dummifiedNoDrop_threeXOutlier     0.899853
# 12        randomForest                ordinal_threeXOutlier     0.900315
# 14        randomForest                  ordinal_allOutliers     0.900703
# 36             xgboost        dummifiedNoDrop_threeXOutlier     0.900806
# 23  randomForest_tuned                  ordinal_allOutliers     0.901122
# 21  randomForest_tuned                ordinal_threeXOutlier     0.901742
# 30             xgboost                ordinal_threeXOutlier     0.902107
# 33             xgboost              dummified_threeXOutlier     0.902148
# 38             xgboost          dummifiedNoDrop_allOutliers     0.904017
# 32             xgboost                  ordinal_allOutliers     0.904445
# 54           scikit_gb        dummifiedNoDrop_threeXOutlier     0.909811
# 51           scikit_gb              dummified_threeXOutlier     0.910339
# 48           scikit_gb                ordinal_threeXOutlier     0.911408
# 16        randomForest        dummified_onlyNormalCondition     0.913220
# 50           scikit_gb                  ordinal_allOutliers     0.913304
# 25  randomForest_tuned        dummified_onlyNormalCondition     0.913875
# 19        randomForest  dummifiedNoDrop_onlyNormalCondition     0.914006
# 53           scikit_gb                dummified_allOutliers     0.914184
# 13        randomForest          ordinal_onlyNormalCondition     0.914710
# 28  randomForest_tuned  dummifiedNoDrop_onlyNormalCondition     0.914974
# 56           scikit_gb          dummifiedNoDrop_allOutliers     0.915274
# 22  randomForest_tuned          ordinal_onlyNormalCondition     0.915665
# 37             xgboost  dummifiedNoDrop_onlyNormalCondition     0.917838
# 34             xgboost        dummified_onlyNormalCondition     0.918049
# 72            catboost        dummifiedNoDrop_threeXOutlier     0.919677
# 31             xgboost          ordinal_onlyNormalCondition     0.919789
# 69            catboost              dummified_threeXOutlier     0.920114
# 63     scikit_gb_tuned        dummifiedNoDrop_threeXOutlier     0.920141
# 74            catboost          dummifiedNoDrop_allOutliers     0.920196
# 60     scikit_gb_tuned              dummified_threeXOutlier     0.920443
# 71            catboost                dummified_allOutliers     0.920787
# 68            catboost                  ordinal_allOutliers     0.920792
# 39       xgboost_tuned                ordinal_threeXOutlier     0.920908
# 57     scikit_gb_tuned                ordinal_threeXOutlier     0.920995
# 66            catboost                ordinal_threeXOutlier     0.921165
# 59     scikit_gb_tuned                  ordinal_allOutliers     0.921607
# 62     scikit_gb_tuned                dummified_allOutliers     0.923153
# 41       xgboost_tuned                  ordinal_allOutliers     0.923575
# 45       xgboost_tuned        dummifiedNoDrop_threeXOutlier     0.923597
# 42       xgboost_tuned              dummified_threeXOutlier     0.924074
# 65     scikit_gb_tuned          dummifiedNoDrop_allOutliers     0.925191
# 81      catboost_tuned        dummifiedNoDrop_threeXOutlier     0.925518
# 44       xgboost_tuned                dummified_allOutliers     0.925717
# 75      catboost_tuned                ordinal_threeXOutlier     0.927600
# 78      catboost_tuned              dummified_threeXOutlier     0.928265
# 10          elasticNet  dummifiedNoDrop_onlyNormalCondition     0.928942
# 83      catboost_tuned          dummifiedNoDrop_allOutliers     0.929797
# 77      catboost_tuned                  ordinal_allOutliers     0.929929
# 47       xgboost_tuned          dummifiedNoDrop_allOutliers     0.930264
# 80      catboost_tuned                dummified_allOutliers     0.930647
# 7                ridge  dummifiedNoDrop_onlyNormalCondition     0.931033
# 4                lasso  dummifiedNoDrop_onlyNormalCondition     0.933296
# 52           scikit_gb        dummified_onlyNormalCondition     0.933338
# 55           scikit_gb  dummifiedNoDrop_onlyNormalCondition     0.934652
# 49           scikit_gb          ordinal_onlyNormalCondition     0.934772
# 73            catboost  dummifiedNoDrop_onlyNormalCondition     0.935308
# 70            catboost        dummified_onlyNormalCondition     0.936520
# 58     scikit_gb_tuned          ordinal_onlyNormalCondition     0.936694
# 67            catboost          ordinal_onlyNormalCondition     0.938718
# 64     scikit_gb_tuned  dummifiedNoDrop_onlyNormalCondition     0.939211
# 61     scikit_gb_tuned        dummified_onlyNormalCondition     0.939710
# 79      catboost_tuned        dummified_onlyNormalCondition     0.944098
# 76      catboost_tuned          ordinal_onlyNormalCondition     0.945148
# 40       xgboost_tuned          ordinal_onlyNormalCondition     0.945529
# 46       xgboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.947439
# 43       xgboost_tuned        dummified_onlyNormalCondition     0.948063
# 82      catboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.949319
#
#     rmse_5kf_mean
# 2    31730.596638
# 0    26329.284397
# 1    25700.214359
# 5    24067.062932
# 8    23982.313218
# 35   24052.156077
# 6    21132.978955
# 11   23648.736387
# 15   21340.686856
# 18   21273.463159
# 17   23829.250646
# 20   23817.907706
# 24   21189.949716
# 9    20924.639689
# 3    20901.033141
# 29   23701.772828
# 26   23693.736189
# 27   21114.207287
# 12   21063.431020
# 14   23595.621432
# 36   20997.812741
# 23   23539.259762
# 21   20919.551383
# 30   20866.299829
# 33   20859.072894
# 38   23207.145705
# 32   23142.592485
# 54   19905.529479
# 51   19856.202269
# 48   19722.476115
# 16   20743.874589
# 50   22060.491907
# 25   20678.952399
# 19   20643.846124
# 53   21953.270181
# 13   20557.040480
# 28   20542.862863
# 56   21797.217046
# 22   20459.591156
# 37   20159.872704
# 34   20111.383128
# 72   18851.435847
# 31   19881.826863
# 69   18766.314419
# 63   18742.033405
# 74   21164.979171
# 60   18689.378815
# 71   21054.910504
# 68   21088.095229
# 39   18584.941593
# 57   18588.952882
# 66   18681.014437
# 59   20968.784077
# 62   20747.332394
# 41   20693.007479
# 45   18238.710501
# 42   18271.906794
# 65   20478.870901
# 81   18059.373184
# 44   20392.851631
# 75   17793.103666
# 78   17773.822390
# 10   18789.042940
# 83   19839.780154
# 77   19829.620391
# 47   19749.971997
# 80   19721.529107
# 7    18516.622484
# 4    18203.509019
# 52   18117.270365
# 55   17922.807704
# 49   17913.941231
# 73   17909.736594
# 70   17705.618147
# 58   17624.355359
# 67   17394.528056
# 64   17275.923095
# 61   17222.610384
# 79   16615.987906
# 76   16470.914927
# 40   16422.205699
# 46   16140.245410
# 43   16036.566846
# 82   15834.922426

# %%
opp_sorted_scores = scores_df.sort_values(by='r2_5kf_mean', ascending = False)
opp_sorted_scores
# Out:
#                  Model                         data_process  r2_5kf_mean  \
# 82      catboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.949319
# 43       xgboost_tuned        dummified_onlyNormalCondition     0.948063
# 46       xgboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.947439
# 40       xgboost_tuned          ordinal_onlyNormalCondition     0.945529
# 76      catboost_tuned          ordinal_onlyNormalCondition     0.945148
# 79      catboost_tuned        dummified_onlyNormalCondition     0.944098
# 61     scikit_gb_tuned        dummified_onlyNormalCondition     0.939710
# 64     scikit_gb_tuned  dummifiedNoDrop_onlyNormalCondition     0.939211
# 67            catboost          ordinal_onlyNormalCondition     0.938718
# 58     scikit_gb_tuned          ordinal_onlyNormalCondition     0.936694
# 70            catboost        dummified_onlyNormalCondition     0.936520
# 73            catboost  dummifiedNoDrop_onlyNormalCondition     0.935308
# 49           scikit_gb          ordinal_onlyNormalCondition     0.934772
# 55           scikit_gb  dummifiedNoDrop_onlyNormalCondition     0.934652
# 52           scikit_gb        dummified_onlyNormalCondition     0.933338
# 4                lasso  dummifiedNoDrop_onlyNormalCondition     0.933296
# 7                ridge  dummifiedNoDrop_onlyNormalCondition     0.931033
# 80      catboost_tuned                dummified_allOutliers     0.930647
# 47       xgboost_tuned          dummifiedNoDrop_allOutliers     0.930264
# 77      catboost_tuned                  ordinal_allOutliers     0.929929
# 83      catboost_tuned          dummifiedNoDrop_allOutliers     0.929797
# 10          elasticNet  dummifiedNoDrop_onlyNormalCondition     0.928942
# 78      catboost_tuned              dummified_threeXOutlier     0.928265
# 75      catboost_tuned                ordinal_threeXOutlier     0.927600
# 44       xgboost_tuned                dummified_allOutliers     0.925717
# 81      catboost_tuned        dummifiedNoDrop_threeXOutlier     0.925518
# 65     scikit_gb_tuned          dummifiedNoDrop_allOutliers     0.925191
# 42       xgboost_tuned              dummified_threeXOutlier     0.924074
# 45       xgboost_tuned        dummifiedNoDrop_threeXOutlier     0.923597
# 41       xgboost_tuned                  ordinal_allOutliers     0.923575
# 62     scikit_gb_tuned                dummified_allOutliers     0.923153
# 59     scikit_gb_tuned                  ordinal_allOutliers     0.921607
# 66            catboost                ordinal_threeXOutlier     0.921165
# 57     scikit_gb_tuned                ordinal_threeXOutlier     0.920995
# 39       xgboost_tuned                ordinal_threeXOutlier     0.920908
# 68            catboost                  ordinal_allOutliers     0.920792
# 71            catboost                dummified_allOutliers     0.920787
# 60     scikit_gb_tuned              dummified_threeXOutlier     0.920443
# 74            catboost          dummifiedNoDrop_allOutliers     0.920196
# 63     scikit_gb_tuned        dummifiedNoDrop_threeXOutlier     0.920141
# 69            catboost              dummified_threeXOutlier     0.920114
# 31             xgboost          ordinal_onlyNormalCondition     0.919789
# 72            catboost        dummifiedNoDrop_threeXOutlier     0.919677
# 34             xgboost        dummified_onlyNormalCondition     0.918049
# 37             xgboost  dummifiedNoDrop_onlyNormalCondition     0.917838
# 22  randomForest_tuned          ordinal_onlyNormalCondition     0.915665
# 56           scikit_gb          dummifiedNoDrop_allOutliers     0.915274
# 28  randomForest_tuned  dummifiedNoDrop_onlyNormalCondition     0.914974
# 13        randomForest          ordinal_onlyNormalCondition     0.914710
# 53           scikit_gb                dummified_allOutliers     0.914184
# 19        randomForest  dummifiedNoDrop_onlyNormalCondition     0.914006
# 25  randomForest_tuned        dummified_onlyNormalCondition     0.913875
# 50           scikit_gb                  ordinal_allOutliers     0.913304
# 16        randomForest        dummified_onlyNormalCondition     0.913220
# 48           scikit_gb                ordinal_threeXOutlier     0.911408
# 51           scikit_gb              dummified_threeXOutlier     0.910339
# 54           scikit_gb        dummifiedNoDrop_threeXOutlier     0.909811
# 32             xgboost                  ordinal_allOutliers     0.904445
# 38             xgboost          dummifiedNoDrop_allOutliers     0.904017
# 33             xgboost              dummified_threeXOutlier     0.902148
# 30             xgboost                ordinal_threeXOutlier     0.902107
# 21  randomForest_tuned                ordinal_threeXOutlier     0.901742
# 23  randomForest_tuned                  ordinal_allOutliers     0.901122
# 36             xgboost        dummifiedNoDrop_threeXOutlier     0.900806
# 14        randomForest                  ordinal_allOutliers     0.900703
# 12        randomForest                ordinal_threeXOutlier     0.900315
# 27  randomForest_tuned        dummifiedNoDrop_threeXOutlier     0.899853
# 26  randomForest_tuned                dummified_allOutliers     0.899785
# 29  randomForest_tuned          dummifiedNoDrop_allOutliers     0.899727
# 3                lasso        dummifiedNoDrop_threeXOutlier     0.899725
# 9           elasticNet        dummifiedNoDrop_threeXOutlier     0.899543
# 24  randomForest_tuned              dummified_threeXOutlier     0.899185
# 20        randomForest          dummifiedNoDrop_allOutliers     0.898781
# 17        randomForest                dummified_allOutliers     0.898702
# 18        randomForest        dummifiedNoDrop_threeXOutlier     0.898322
# 15        randomForest              dummified_threeXOutlier     0.897686
# 11          elasticNet          dummifiedNoDrop_allOutliers     0.897469
# 6                ridge        dummifiedNoDrop_threeXOutlier     0.897200
# 35             xgboost                dummified_allOutliers     0.896948
# 8                ridge          dummifiedNoDrop_allOutliers     0.893286
# 5                lasso          dummifiedNoDrop_allOutliers     0.891631
# 1                  MLR        dummified_onlyNormalCondition     0.867671
# 0                  MLR              dummified_threeXOutlier     0.842156
# 2                  MLR                dummified_allOutliers     0.817061
#
#     rmse_5kf_mean
# 82   15834.922426
# 43   16036.566846
# 46   16140.245410
# 40   16422.205699
# 76   16470.914927
# 79   16615.987906
# 61   17222.610384
# 64   17275.923095
# 67   17394.528056
# 58   17624.355359
# 70   17705.618147
# 73   17909.736594
# 49   17913.941231
# 55   17922.807704
# 52   18117.270365
# 4    18203.509019
# 7    18516.622484
# 80   19721.529107
# 47   19749.971997
# 77   19829.620391
# 83   19839.780154
# 10   18789.042940
# 78   17773.822390
# 75   17793.103666
# 44   20392.851631
# 81   18059.373184
# 65   20478.870901
# 42   18271.906794
# 45   18238.710501
# 41   20693.007479
# 62   20747.332394
# 59   20968.784077
# 66   18681.014437
# 57   18588.952882
# 39   18584.941593
# 68   21088.095229
# 71   21054.910504
# 60   18689.378815
# 74   21164.979171
# 63   18742.033405
# 69   18766.314419
# 31   19881.826863
# 72   18851.435847
# 34   20111.383128
# 37   20159.872704
# 22   20459.591156
# 56   21797.217046
# 28   20542.862863
# 13   20557.040480
# 53   21953.270181
# 19   20643.846124
# 25   20678.952399
# 50   22060.491907
# 16   20743.874589
# 48   19722.476115
# 51   19856.202269
# 54   19905.529479
# 32   23142.592485
# 38   23207.145705
# 33   20859.072894
# 30   20866.299829
# 21   20919.551383
# 23   23539.259762
# 36   20997.812741
# 14   23595.621432
# 12   21063.431020
# 27   21114.207287
# 26   23693.736189
# 29   23701.772828
# 3    20901.033141
# 9    20924.639689
# 24   21189.949716
# 20   23817.907706
# 17   23829.250646
# 18   21273.463159
# 15   21340.686856
# 11   23648.736387
# 6    21132.978955
# 35   24052.156077
# 8    23982.313218
# 5    24067.062932
# 1    25700.214359
# 0    26329.284397
# 2    31730.596638

# %%
scores_df.sort_values(by='r2_5kf_mean').tail(10)
# Out:
#               Model                         data_process  r2_5kf_mean  \
# 58  scikit_gb_tuned          ordinal_onlyNormalCondition     0.936694
# 67         catboost          ordinal_onlyNormalCondition     0.938718
# 64  scikit_gb_tuned  dummifiedNoDrop_onlyNormalCondition     0.939211
# 61  scikit_gb_tuned        dummified_onlyNormalCondition     0.939710
# 79   catboost_tuned        dummified_onlyNormalCondition     0.944098
# 76   catboost_tuned          ordinal_onlyNormalCondition     0.945148
# 40    xgboost_tuned          ordinal_onlyNormalCondition     0.945529
# 46    xgboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.947439
# 43    xgboost_tuned        dummified_onlyNormalCondition     0.948063
# 82   catboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.949319
#
#     rmse_5kf_mean
# 58   17624.355359
# 67   17394.528056
# 64   17275.923095
# 61   17222.610384
# 79   16615.987906
# 76   16470.914927
# 40   16422.205699
# 46   16140.245410
# 43   16036.566846
# 82   15834.922426

# %%
#If the model includes '_tuned' I used Optuna to tune the hyperparameters

# %%
#before hyperparameter tuning xgboost, r2 = 0.907785 and rmse = 20254.617265

# %%
# Set up the figure and axes
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar width
bar_width = 0.35

# Position of bars on X-axis
r1 = range(len(sorted_scores['Model']))
r2 = [x + bar_width for x in r1]

# Plot R2 bars on the primary y-axis (left)
ax1.bar(r1, sorted_scores['r2_5kf_mean'], color='b', width=bar_width, edgecolor='grey', label='R2')

# Create a secondary y-axis (right) for RMSE
ax2 = ax1.twinx()
ax2.bar(r2, sorted_scores['rmse_5kf_mean'], color='r', width=bar_width, edgecolor='grey', label='RMSE')

# Add labels, title, and legend
ax1.set_xlabel('Model Type', fontweight='bold', fontsize=15)
ax1.set_ylabel('R2', fontweight='bold', color='b', fontsize=15)
ax2.set_ylabel('RMSE', fontweight='bold', color='r', fontsize=15)
ax1.set_xticks([r + bar_width / 2 for r in range(len(sorted_scores['Model']))])
ax1.set_xticklabels(sorted_scores['Model'], rotation=45, ha='right')  # Adjust rotation angle as needed

# Move the legend outside the chart
ax1.legend(loc='upper left', bbox_to_anchor=(-0.2, 1))
ax2.legend(loc='upper right', bbox_to_anchor=(1.2, 1))

# Show the plot
plt.show()

# %%
sorted_scores
# Out:
#               Model                         data_process  r2_5kf_mean  \
# 82   catboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.949319
# 43    xgboost_tuned        dummified_onlyNormalCondition     0.948063
# 46    xgboost_tuned  dummifiedNoDrop_onlyNormalCondition     0.947439
# 40    xgboost_tuned          ordinal_onlyNormalCondition     0.945529
# 76   catboost_tuned          ordinal_onlyNormalCondition     0.945148
# 79   catboost_tuned        dummified_onlyNormalCondition     0.944098
# 61  scikit_gb_tuned        dummified_onlyNormalCondition     0.939710
# 64  scikit_gb_tuned  dummifiedNoDrop_onlyNormalCondition     0.939211
# 67         catboost          ordinal_onlyNormalCondition     0.938718
# 58  scikit_gb_tuned          ordinal_onlyNormalCondition     0.936694
#
#     rmse_5kf_mean
# 82   15834.922426
# 43   16036.566846
# 46   16140.245410
# 40   16422.205699
# 76   16470.914927
# 79   16615.987906
# 61   17222.610384
# 64   17275.923095
# 67   17394.528056
# 58   17624.355359

# %%
sorted_scores = scores_df.copy()

# %%
# Pivot the DataFrame for better plotting
pivot_df = sorted_scores.pivot(index='data_process', columns='Model', values='r2_5kf_mean')

# Plotting
plt.figure(figsize=(15, 8))
pivot_df.plot(marker='o', linestyle='-', ax=plt.gca())

# Customize the plot
plt.title('Model Performance across Data Processing Steps')
plt.xlabel('Data Processing Steps')
plt.ylabel('R2 5KF Mean')
plt.legend(title='Model', bbox_to_anchor=(1, 1), loc='upper left')
# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.cm as cm
# Calculate mean R2 scores for each model and sort them in descending order
mean_r2_by_model = sorted_scores.groupby('Model')['r2_5kf_mean'].mean().sort_values(ascending=False)

# Reorder the columns of pivot_df based on the sorted order of models
pivot_df_sorted = pivot_df[mean_r2_by_model.index]

# Get the number of unique models
num_models = len(mean_r2_by_model)

# Choose a colormap with enough distinct colors
colors = cm.tab20(np.linspace(0, 1, num_models))

# Plotting
plt.figure(figsize=(15, 8))
pivot_df_sorted.plot(marker='o', linestyle='-', ax=plt.gca(), color=colors)

# Customize the plot
plt.title('Model Performance across Data Processing Steps')
plt.xlabel('Data Processing Steps')
plt.ylabel('R2 5KF Mean')

# Create a legend with sorted order of models
plt.legend(title='Model', bbox_to_anchor=(1, 1), loc='upper left', labels=mean_r2_by_model.index)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
